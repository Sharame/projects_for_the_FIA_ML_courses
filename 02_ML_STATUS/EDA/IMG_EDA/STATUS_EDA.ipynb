# %% [markdown]
# #**CELLA 1 - Setup & Load Data**

# %%
# ═══════════════════════════════════════════════════════════
# STATUS MODULE - EDA v2.0 (Sampled Dataset)
# ═══════════════════════════════════════════════════════════

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Styling
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("="*80)
print("STATUS MODULE - EXPLORATORY DATA ANALYSIS v2.0")
print("="*80)

# ════════════════════════════════════════════════════════════
# LOAD SAMPLED DATASET
# ════════════════════════════════════════════════════════════

DATADIR = 'data/synth_set_level_v2'

print("\nLoading sampled datasets...")

df_users = pd.read_csv(f'{DATADIR}/users_sampled.csv')
df_sets = pd.read_csv(f'{DATADIR}/workout_sets_sampled.csv')
df_workouts = pd.read_csv(f'{DATADIR}/workouts_sampled.csv')

# Parse dates
df_sets['date'] = pd.to_datetime(df_sets['date'])
df_workouts['date'] = pd.to_datetime(df_workouts['date'])

print(f"[OK] Users: {len(df_users):,}")
print(f"[OK] Sets: {len(df_sets):,}")
print(f"[OK] Workouts: {len(df_workouts):,}")

# ════════════════════════════════════════════════════════════
# TARGET DISTRIBUTION
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("TARGET DISTRIBUTION (experience_label)")
print("-"*80)

exp_counts = df_users['experience_label'].value_counts().sort_index()
for label, count in exp_counts.items():
    pct = count / len(df_users) * 100
    print(f"{label:12s}: {count:3d} ({pct:5.1f}%)")

# Imbalance ratio
max_class = exp_counts.max()
min_class = exp_counts.min()
imbalance_ratio = max_class / min_class

print(f"\nImbalance ratio: {imbalance_ratio:.2f}:1")

if imbalance_ratio > 3:
    print("[!]  Class imbalance detected (>3:1)")
else:
    print("[OK] Classes balanced")

print("="*80)
# Out:
# ================================================================================
# STATUS MODULE - EXPLORATORY DATA ANALYSIS v2.0
# ================================================================================
#
# Loading sampled datasets...
# [OK] Users: 510
# [OK] Sets: 1,566,944
# [OK] Workouts: 106,571
#
# --------------------------------------------------------------------------------
# TARGET DISTRIBUTION (experience_label)
# --------------------------------------------------------------------------------
# Advanced    : 170 ( 33.3%)
# Beginner    : 170 ( 33.3%)
# Intermediate: 170 ( 33.3%)
#
# Imbalance ratio: 1.00:1
# [OK] Classes balanced
# ================================================================================

# %% [markdown]
# #**CELLA 2 - Compute User-Level Aggregations**

# %%
# ═══════════════════════════════════════════════════════════
# USER-LEVEL FEATURE AGGREGATIONS
# ═══════════════════════════════════════════════════════════

print("="*80)
print("COMPUTING USER-LEVEL AGGREGATIONS")
print("="*80)

# ════════════════════════════════════════════════════════════
# Basic Stats per User
# ════════════════════════════════════════════════════════════

print("\n1. Basic workout statistics...")

user_agg_basic = df_sets.groupby('user_id').agg({
    'load_done_kg': ['mean', 'std', 'min', 'max'],
    'reps_done': ['mean', 'std'],
    'rpe_done': ['mean', 'std'],
    'set_id': 'count'  # Total sets
}).reset_index()

# Flatten columns
user_agg_basic.columns = ['user_id', 'load_mean', 'load_std', 'load_min', 'load_max',
                          'reps_mean', 'reps_std', 'rpe_mean', 'rpe_std', 'total_sets']

print(f"[OK] Aggregated {len(user_agg_basic)} users")

# ════════════════════════════════════════════════════════════
# ACWR Stats
# ════════════════════════════════════════════════════════════

print("2. ACWR statistics...")

user_acwr = df_sets.groupby('user_id').agg({
    'acwr': 'mean'
}).reset_index()
user_acwr.columns = ['user_id', 'acwr_mean']

# --- FIX: spike_weeks_count = numero di settimane (non numero di set) ---

# 1) normalizza week_type (evita valori tipo 'sp')
df_sets['week_type'] = (df_sets['week_type'].astype(str).str.strip().str.lower()
                        .replace({'sp': 'spike'}))

# 2) definisci un week_id (settimana ISO-like; scegli il giorno di chiusura settimana)
# W-MON = settimane che terminano il lunedì (si possono usare W-SUN, W-MON, ecc.)
df_sets['week_id'] = df_sets['date'].dt.to_period('W-SUN')

# 3) conta settimane spike uniche per utente
spike_counts = (df_sets[df_sets['week_type'].eq('spike')]
                .drop_duplicates(['user_id', 'week_id'])
                .groupby('user_id')
                .size()
                .reset_index(name='spike_weeks_count'))

# Merge
user_agg = user_agg_basic.merge(user_acwr, on='user_id', how='left')
user_agg = user_agg.merge(spike_counts, on='user_id', how='left')
user_agg['spike_weeks_count'] = user_agg['spike_weeks_count'].fillna(0).astype(int)

print(f"[OK] ACWR and spike counts added")

# ════════════════════════════════════════════════════════════
# Workout Frequency
# ════════════════════════════════════════════════════════════

print("3. Workout frequency...")

# Count workouts per user
workout_counts = df_workouts.groupby('user_id').size().reset_index(name='total_workouts')

# Calculate duration
user_duration = df_workouts.groupby('user_id')['date'].agg(['min', 'max']).reset_index()
user_duration['duration_days'] = (user_duration['max'] - user_duration['min']).dt.days + 1
user_duration['duration_weeks'] = user_duration['duration_days'] / 7.0

# Observed frequency (workouts/week)
workout_counts = workout_counts.merge(user_duration[['user_id', 'duration_weeks']], on='user_id')
workout_counts['observed_freq_weekly'] = workout_counts['total_workouts'] / workout_counts['duration_weeks']

# Merge
user_agg = user_agg.merge(
    workout_counts[['user_id', 'observed_freq_weekly']],
    on='user_id',
    how='left'
)

print(f"[OK] Frequency calculated")

# ════════════════════════════════════════════════════════════
# Skip Rate & Consistency (from workouts)
# ════════════════════════════════════════════════════════════

print("4. Skip rate and consistency...")

skip_stats = df_workouts.groupby('user_id')['workout_status'].apply(
    lambda x: (x == 'skipped').sum() / len(x) if len(x) > 0 else 0.0
).reset_index(name='skip_rate')

user_agg = user_agg.merge(skip_stats, on='user_id', how='left')

# Consistency from df_users
user_agg = user_agg.merge(
    df_users[['user_id', 'consistency_score', 'experience_label']],
    on='user_id',
    how='left'
)

print(f"[OK] Skip rate and consistency added")

# ════════════════════════════════════════════════════════════
# Load Progression (Slope)
# ════════════════════════════════════════════════════════════

print("5. Load progression (slope regression)...")

def calculate_load_progression(user_df):
    """Calculate slope of load over time (linear regression)"""
    if len(user_df) < 10:
        return 0.0

    user_df = user_df.sort_values('date').reset_index(drop=True)
    user_df = user_df.dropna(subset=['load_done_kg'])

    if len(user_df) < 10:
        return 0.0

    # Time index (days from start)
    user_df['days_from_start'] = (user_df['date'] - user_df['date'].min()).dt.days

    # Linear regression
    slope, intercept, r_value, p_value, std_err = stats.linregress(
        user_df['days_from_start'],
        user_df['load_done_kg']
    )

    # Normalize: slope per 30 days (monthly rate)
    slope_monthly = slope * 30

    # Convert to multiplier (1.0 = no change, 1.1 = +10% per month)
    if intercept > 0:
        progression = 1.0 + (slope_monthly / intercept)
    else:
        progression = 1.0

    return float(np.clip(progression, 0.5, 2.0))

load_progressions = []

for uid in user_agg['user_id']:
    user_sets = df_sets[df_sets['user_id'] == uid]
    prog = calculate_load_progression(user_sets)
    load_progressions.append({'user_id': uid, 'load_progression': prog})

load_prog_df = pd.DataFrame(load_progressions)
user_agg = user_agg.merge(load_prog_df, on='user_id', how='left')

print(f"[OK] Load progression calculated")

# ════════════════════════════════════════════════════════════
# Composite Features
# ════════════════════════════════════════════════════════════

print("6. Composite features...")

user_agg['volume_score'] = user_agg['total_sets'] * user_agg['observed_freq_weekly']
user_agg['intensity_score'] = user_agg['load_mean'] * user_agg['reps_mean']
user_agg['rpe_volume_interaction'] = user_agg['rpe_mean'] * user_agg['reps_mean']

print(f"[OK] Composite features added")

# ════════════════════════════════════════════════════════════
# FINAL DATASET
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("FINAL AGGREGATED DATASET")
print("-"*80)
print(f"[OK] Shape: {user_agg.shape}")
print(f"[OK] Features: {user_agg.shape[1] - 2} (excluding user_id, experience_label)")
print(f"[OK] Users: {len(user_agg)}")

print("\nColumn list:")
print(user_agg.columns.tolist())

print("\nPreview (first 5):")
print(user_agg.head())

print("="*80)
# Out:
# ================================================================================
# COMPUTING USER-LEVEL AGGREGATIONS
# ================================================================================
#
# 1. Basic workout statistics...
# [OK] Aggregated 510 users
# 2. ACWR statistics...
# [OK] ACWR and spike counts added
# 3. Workout frequency...
# [OK] Frequency calculated
# 4. Skip rate and consistency...
# [OK] Skip rate and consistency added
# 5. Load progression (slope regression)...
# [OK] Load progression calculated
# 6. Composite features...
# [OK] Composite features added
#
# --------------------------------------------------------------------------------
# FINAL AGGREGATED DATASET
# --------------------------------------------------------------------------------
# [OK] Shape: (510, 20)
# [OK] Features: 18 (excluding user_id, experience_label)
# [OK] Users: 510
#
# Column list:
# ['user_id', 'load_mean', 'load_std', 'load_min', 'load_max', 'reps_mean', 'reps_std', 'rpe_mean', 'rpe_std', 'total_sets', 'acwr_mean', 'spike_weeks_count', 'observed_freq_weekly', 'skip_rate', 'consistency_score', 'experience_label', 'load_progression', 'volume_score', 'intensity_score', 'rpe_volume_interaction']
#
# Preview (first 5):
#    user_id  load_mean   load_std  load_min  load_max  reps_mean  reps_std  \
# 0        2  24.738577   2.537616     18.25     32.50   8.895833  2.311940
# 1        4  26.363202   3.388975     19.75     37.25   8.654118  2.122933
# 2        8  66.282138  26.721539     26.00    174.25   8.642820  2.058451
# 3       10  33.272371   4.436431     23.50     47.50   8.857664  2.273090
# 4       15  19.710349   1.784468     15.00     24.75   9.008011  2.089556
#
#    rpe_mean   rpe_std  total_sets  acwr_mean  spike_weeks_count  \
# 0  5.369393  2.085070         768   1.266623                 10
# 1  4.483715  1.243112         850   1.101414                  1
# 2  4.680819  0.595377        9743   1.099030                 19
# 3  4.547641  1.497930        1096   1.213650                 21
# 4  5.155055  1.362308         749   1.186722                  6
#
#    observed_freq_weekly  skip_rate  consistency_score experience_label  \
# 0              2.967078   0.233010               0.65         Beginner
# 1              1.812057   0.095890               0.75     Intermediate
# 2              3.629356   0.065173               0.85         Advanced
# 3              2.803241   0.098266               0.75     Intermediate
# 4              3.655556   0.180851               0.65         Beginner
#
#    load_progression  volume_score  intensity_score  rpe_volume_interaction
# 0          1.033016   2278.716049       220.070258               47.765226
# 1          1.001101   1540.248227       228.150251               38.802600
# 2          1.097704  35360.814150       572.864617               40.455476
# 3          1.032960   3072.351852       294.715489               40.281478
# 4          1.030218   2738.011111       177.551038               46.436787
# ================================================================================

# %% [markdown]
# #**CELLA 3 - Statistiche Descrittive per Experience Level**

# %%
# ═══════════════════════════════════════════════════════════
# DESCRIPTIVE STATISTICS per EXPERIENCE LEVEL
# ═══════════════════════════════════════════════════════════

print("="*80)
print("DESCRIPTIVE STATISTICS per EXPERIENCE LEVEL")
print("="*80)

# Feature numeriche chiave da analizzare
key_features = [
    'load_mean', 'reps_mean', 'rpe_mean', 'total_sets',
    'acwr_mean', 'spike_weeks_count', 'load_progression',
    'observed_freq_weekly', 'skip_rate', 'consistency_score'
]

for feat in key_features:
    print(f"\n{'='*80}")
    print(f"FEATURE: {feat}")
    print("="*80)

    stats_by_exp = user_agg.groupby('experience_label')[feat].agg([
        'count', 'mean', 'std', 'min',
        ('q25', lambda x: x.quantile(0.25)),
        ('median', 'median'),
        ('q75', lambda x: x.quantile(0.75)),
        'max'
    ]).round(2)

    print(stats_by_exp)

    # Cohen's d (Beginner vs Advanced)
    beg_vals = user_agg[user_agg['experience_label'] == 'Beginner'][feat].dropna()
    adv_vals = user_agg[user_agg['experience_label'] == 'Advanced'][feat].dropna()

    if len(beg_vals) > 0 and len(adv_vals) > 0:
        pooled_std = np.sqrt(((len(beg_vals)-1)*beg_vals.std()**2 +
                              (len(adv_vals)-1)*adv_vals.std()**2) /
                             (len(beg_vals) + len(adv_vals) - 2))

        cohens_d = abs(beg_vals.mean() - adv_vals.mean()) / pooled_std if pooled_std > 0 else 0.0

        print(f"\n[OK] Cohen's d (Beginner vs Advanced): {cohens_d:.3f}")

        if cohens_d < 0.2:
            print("  -> Effetto TRASCURABILE (feature NON discrimina)")
        elif cohens_d < 0.5:
            print("  -> Effetto PICCOLO")
        elif cohens_d < 0.8:
            print("  -> Effetto MEDIO")
        else:
            print("  -> Effetto GRANDE (feature discrimina BENE)")

print("\n" + "="*80)
print("[OK] Descriptive statistics complete")
print("="*80)
# Out:
# ================================================================================
# DESCRIPTIVE STATISTICS per EXPERIENCE LEVEL
# ================================================================================
#
# ================================================================================
# FEATURE: load_mean
# ================================================================================
#                   count   mean    std    min    q25  median    q75     max
# experience_label
# Advanced            170  68.69  23.55  34.16  52.10   60.56  78.02  144.41
# Beginner            170  19.70   1.57  15.93  18.76   19.66  20.51   25.57
# Intermediate        170  33.45   5.66  22.75  29.75   31.94  36.10   61.31
#
# [OK] Cohen's d (Beginner vs Advanced): 2.935
#   -> Effetto GRANDE (feature discrimina BENE)
#
# ================================================================================
# FEATURE: reps_mean
# ================================================================================
#                   count  mean   std   min   q25  median   q75   max
# experience_label
# Advanced            170  8.68  0.06  8.56  8.64    8.66  8.69  8.86
# Beginner            170  8.96  0.10  8.62  8.89    8.95  9.02  9.21
# Intermediate        170  8.72  0.09  8.55  8.66    8.70  8.79  9.04
#
# [OK] Cohen's d (Beginner vs Advanced): 3.302
#   -> Effetto GRANDE (feature discrimina BENE)
#
# ================================================================================
# FEATURE: rpe_mean
# ================================================================================
#                   count  mean   std   min   q25  median   q75   max
# experience_label
# Advanced            170  4.59  0.22  4.04  4.43    4.59  4.76  5.07
# Beginner            170  5.10  0.23  4.58  4.95    5.08  5.28  5.65
# Intermediate        170  4.73  0.20  4.29  4.58    4.73  4.89  5.12
#
# [OK] Cohen's d (Beginner vs Advanced): 2.211
#   -> Effetto GRANDE (feature discrimina BENE)
#
# ================================================================================
# FEATURE: total_sets
# ================================================================================
#                   count     mean      std   min      q25  median     q75  \
# experience_label
# Advanced            170  6042.58  2857.48  1461  3896.00  5382.5  8057.0
# Beginner            170   723.41   358.38   125   443.75   661.5   901.5
# Intermediate        170  2451.34  1371.33   410  1386.75  2106.0  3160.5
#
#                     max
# experience_label
# Advanced          13527
# Beginner           1802
# Intermediate       7159
#
# [OK] Cohen's d (Beginner vs Advanced): 2.612
#   -> Effetto GRANDE (feature discrimina BENE)
#
# ================================================================================
# FEATURE: acwr_mean
# ================================================================================
#                   count  mean   std   min   q25  median   q75   max
# experience_label
# Advanced            170  1.09  0.02  1.03  1.08    1.09  1.11  1.16
# Beginner            170  1.20  0.07  1.03  1.15    1.20  1.24  1.39
# Intermediate        170  1.14  0.04  1.05  1.11    1.14  1.17  1.23
#
# [OK] Cohen's d (Beginner vs Advanced): 2.162
#   -> Effetto GRANDE (feature discrimina BENE)
#
# ================================================================================
# FEATURE: spike_weeks_count
# ================================================================================
#                   count  mean   std  min  q25  median   q75  max
# experience_label
# Advanced            170  9.48  4.87    0  6.0     9.0  12.0   25
# Beginner            170  6.84  3.75    0  4.0     7.0   9.0   19
# Intermediate        170  9.80  5.14    1  6.0     9.0  13.0   24
#
# [OK] Cohen's d (Beginner vs Advanced): 0.608
#   -> Effetto MEDIO
#
# ================================================================================
# FEATURE: load_progression
# ================================================================================
#                   count  mean   std   min   q25  median   q75   max
# experience_label
# Advanced            170  1.18  0.23  1.00  1.05    1.08  1.16  2.00
# Beginner            170  1.01  0.01  0.95  1.01    1.01  1.02  1.05
# Intermediate        170  1.05  0.06  0.98  1.02    1.04  1.06  1.53
#
# [OK] Cohen's d (Beginner vs Advanced): 1.000
#   -> Effetto GRANDE (feature discrimina BENE)
#
# ================================================================================
# FEATURE: observed_freq_weekly
# ================================================================================
#                   count  mean   std   min   q25  median   q75   max
# experience_label
# Advanced            170  3.16  0.76  1.00  2.71    3.30  3.64  4.76
# Beginner            170  3.13  0.81  1.02  2.73    3.24  3.66  4.97
# Intermediate        170  3.11  0.84  1.01  2.66    3.11  3.63  5.08
#
# [OK] Cohen's d (Beginner vs Advanced): 0.041
#   -> Effetto TRASCURABILE (feature NON discrimina)
#
# ================================================================================
# FEATURE: skip_rate
# ================================================================================
#                   count  mean   std   min   q25  median   q75   max
# experience_label
# Advanced            170  0.07  0.02  0.04  0.06    0.07  0.08  0.12
# Beginner            170  0.21  0.05  0.11  0.17    0.21  0.25  0.38
# Intermediate        170  0.12  0.03  0.03  0.10    0.11  0.13  0.20
#
# [OK] Cohen's d (Beginner vs Advanced): 3.657
#   -> Effetto GRANDE (feature discrimina BENE)
#
# ================================================================================
# FEATURE: consistency_score
# ================================================================================
#                   count  mean  std   min   q25  median   q75   max
# experience_label
# Advanced            170  0.85  0.0  0.85  0.85    0.85  0.85  0.85
# Beginner            170  0.65  0.0  0.65  0.65    0.65  0.65  0.65
# Intermediate        170  0.75  0.0  0.75  0.75    0.75  0.75  0.75
#
# [OK] Cohen's d (Beginner vs Advanced): 88062699062100.469
#   -> Effetto GRANDE (feature discrimina BENE)
#
# ================================================================================
# [OK] Descriptive statistics complete
# ================================================================================

# %% [markdown]
# #**CELLA 4 - Correlation Matrix (Verifica Leakage)**

# %%
# ═══════════════════════════════════════════════════════════
# CORRELATION MATRIX - LEAKAGE CHECK
# ═══════════════════════════════════════════════════════════

print("="*80)
print("CORRELATION MATRIX - LEAKAGE CHECK")
print("="*80)

# Target encoding (per correlation numerica)
target_encoding = {'Beginner': 0, 'Intermediate': 1, 'Advanced': 2}
user_agg['target_encoded'] = user_agg['experience_label'].map(target_encoding)

# Feature per correlation
corr_features = [
    'load_mean', 'reps_mean', 'rpe_mean', 'total_sets',
    'acwr_mean', 'spike_weeks_count', 'load_progression',
    'observed_freq_weekly', 'skip_rate', 'consistency_score',
    'volume_score', 'intensity_score', 'rpe_volume_interaction',
    'target_encoded'
]

corr_features = [f for f in corr_features if f != 'consistency_score']

corr_matrix = user_agg[corr_features].corr()

print("\n" + "-"*80)
print("ALL CORRELATIONS SORTED (by absolute value)")
print("-"*80)

all_corr = []

for i in range(len(corr_matrix.columns)):
    for j in range(i + 1, len(corr_matrix.columns)):
        feat_1 = corr_matrix.columns[i]
        feat_2 = corr_matrix.columns[j]
        corr_val = corr_matrix.iloc[i, j]
        all_corr.append((feat_1, feat_2, corr_val))

# Ordina per valore assoluto
all_corr = sorted(all_corr, key=lambda x: abs(x[2]), reverse=True)

for feat_1, feat_2, corr_val in all_corr:
    print(f"{feat_1:25s} <-> {feat_2:25s}: {corr_val:+.3f}")

print("-"*80)

# ════════════════════════════════════════════════════════════
# Correlation con Target
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("CORRELATION con TARGET (experience_label)")
print("-"*80)

target_corr = corr_matrix['target_encoded'].drop('target_encoded').sort_values(
    key=abs, ascending=False
)

print("\nTop correlations (absolute value):\n")
for feat, corr_val in target_corr.items():
    print(f"{feat:25s}: {corr_val:+.3f}")

    # Flag leakage risk
    if abs(corr_val) > 0.85:
        print(f"  [!]  HIGH LEAKAGE RISK (|r| > 0.85)")
    elif abs(corr_val) > 0.70:
        print(f"  [MODERATE] MODERATE correlation")
    elif abs(corr_val) > 0.40:
        print(f"  [OK] Good discriminative power")
    else:
        print(f"  [SAFE] Weak correlation ")

# ════════════════════════════════════════════════════════════
# Heatmap Visualization
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("CORRELATION HEATMAP")
print("-"*80)

plt.figure(figsize=(14, 12))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt='.2f',
    cmap='coolwarm',
    center=0,
    vmin=-1,
    vmax=1,
    square=True,
    linewidths=0.5
)
plt.title('Correlation Matrix - STATUS Features', fontsize=16, weight='bold')
plt.tight_layout()
plt.savefig('correlation_matrix_STATUS_v2.png', dpi=150, bbox_inches='tight')
plt.show()

print("[OK] Heatmap saved: correlation_matrix_STATUS_v2.png")
print("="*80)
# Out:
# ================================================================================
# CORRELATION MATRIX - LEAKAGE CHECK
# ================================================================================
#
# --------------------------------------------------------------------------------
# ALL CORRELATIONS SORTED (by absolute value)
# --------------------------------------------------------------------------------
# load_mean                 <-> intensity_score          : +1.000
# rpe_mean                  <-> rpe_volume_interaction   : +0.980
# total_sets                <-> volume_score             : +0.971
# skip_rate                 <-> target_encoded           : -0.839
# load_mean                 <-> target_encoded           : +0.803
# intensity_score           <-> target_encoded           : +0.796
# reps_mean                 <-> target_encoded           : -0.761
# rpe_volume_interaction    <-> target_encoded           : -0.756
# total_sets                <-> target_encoded           : +0.755
# load_progression          <-> intensity_score          : +0.733
# load_mean                 <-> load_progression         : +0.729
# acwr_mean                 <-> target_encoded           : -0.691
# reps_mean                 <-> rpe_volume_interaction   : +0.680
# skip_rate                 <-> rpe_volume_interaction   : +0.675
# rpe_mean                  <-> target_encoded           : -0.673
# volume_score              <-> target_encoded           : +0.668
# load_mean                 <-> total_sets               : +0.667
# reps_mean                 <-> skip_rate                : +0.663
# total_sets                <-> intensity_score          : +0.659
# load_mean                 <-> volume_score             : +0.651
# volume_score              <-> intensity_score          : +0.643
# load_mean                 <-> skip_rate                : -0.637
# reps_mean                 <-> total_sets               : -0.633
# skip_rate                 <-> intensity_score          : -0.631
# total_sets                <-> skip_rate                : -0.625
# rpe_mean                  <-> skip_rate                : +0.606
# acwr_mean                 <-> skip_rate                : +0.576
# reps_mean                 <-> volume_score             : -0.561
# skip_rate                 <-> volume_score             : -0.557
# total_sets                <-> rpe_volume_interaction   : -0.551
# load_mean                 <-> acwr_mean                : -0.547
# acwr_mean                 <-> intensity_score          : -0.542
# load_mean                 <-> rpe_volume_interaction   : -0.531
# intensity_score           <-> rpe_volume_interaction   : -0.524
# acwr_mean                 <-> rpe_volume_interaction   : +0.524
# reps_mean                 <-> rpe_mean                 : +0.519
# reps_mean                 <-> acwr_mean                : +0.512
# total_sets                <-> acwr_mean                : -0.500
# load_mean                 <-> reps_mean                : -0.499
# volume_score              <-> rpe_volume_interaction   : -0.492
# reps_mean                 <-> intensity_score          : -0.485
# load_mean                 <-> rpe_mean                 : -0.482
# rpe_mean                  <-> intensity_score          : -0.479
# rpe_mean                  <-> total_sets               : -0.472
# rpe_mean                  <-> acwr_mean                : +0.471
# observed_freq_weekly      <-> volume_score             : +0.437
# acwr_mean                 <-> volume_score             : -0.437
# load_progression          <-> target_encoded           : +0.432
# rpe_mean                  <-> volume_score             : -0.422
# load_progression          <-> skip_rate                : -0.339
# spike_weeks_count         <-> volume_score             : +0.330
# total_sets                <-> spike_weeks_count        : +0.325
# load_progression          <-> volume_score             : +0.292
# total_sets                <-> observed_freq_weekly     : +0.290
# total_sets                <-> load_progression         : +0.278
# acwr_mean                 <-> load_progression         : -0.274
# load_mean                 <-> spike_weeks_count        : +0.268
# spike_weeks_count         <-> intensity_score          : +0.266
# spike_weeks_count         <-> skip_rate                : -0.263
# load_progression          <-> rpe_volume_interaction   : -0.262
# rpe_mean                  <-> load_progression         : -0.248
# acwr_mean                 <-> spike_weeks_count        : +0.242
# spike_weeks_count         <-> observed_freq_weekly     : +0.228
# spike_weeks_count         <-> target_encoded           : +0.225
# load_progression          <-> observed_freq_weekly     : +0.218
# observed_freq_weekly      <-> intensity_score          : +0.218
# load_mean                 <-> observed_freq_weekly     : +0.216
# reps_mean                 <-> spike_weeks_count        : -0.211
# reps_mean                 <-> load_progression         : -0.208
# spike_weeks_count         <-> rpe_volume_interaction   : -0.195
# spike_weeks_count         <-> load_progression         : +0.181
# rpe_mean                  <-> spike_weeks_count        : -0.170
# acwr_mean                 <-> observed_freq_weekly     : +0.064
# observed_freq_weekly      <-> rpe_volume_interaction   : -0.017
# observed_freq_weekly      <-> skip_rate                : -0.017
# rpe_mean                  <-> observed_freq_weekly     : -0.017
# observed_freq_weekly      <-> target_encoded           : +0.016
# reps_mean                 <-> observed_freq_weekly     : -0.015
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# CORRELATION con TARGET (experience_label)
# --------------------------------------------------------------------------------
#
# Top correlations (absolute value):
#
# skip_rate                : -0.839
#   [MODERATE] MODERATE correlation
# load_mean                : +0.803
#   [MODERATE] MODERATE correlation
# intensity_score          : +0.796
#   [MODERATE] MODERATE correlation
# reps_mean                : -0.761
#   [MODERATE] MODERATE correlation
# rpe_volume_interaction   : -0.756
#   [MODERATE] MODERATE correlation
# total_sets               : +0.755
#   [MODERATE] MODERATE correlation
# acwr_mean                : -0.691
#   [OK] Good discriminative power
# rpe_mean                 : -0.673
#   [OK] Good discriminative power
# volume_score             : +0.668
#   [OK] Good discriminative power
# load_progression         : +0.432
#   [OK] Good discriminative power
# spike_weeks_count        : +0.225
#   [SAFE] Weak correlation
# observed_freq_weekly     : +0.016
#   [SAFE] Weak correlation
#
# --------------------------------------------------------------------------------
# CORRELATION HEATMAP
# --------------------------------------------------------------------------------
# [OK] Heatmap saved: correlation_matrix_STATUS_v2.png
# ================================================================================

# %% [markdown]
# # **CELLA 5 - FEATURE SELECTION**

# %%
# ═══════════════════════════════════════════════════════════
# FEATURE SELECTION v2.2
# ═══════════════════════════════════════════════════════════

print("="*80)
print("FEATURE SELECTION v2.2 (LEAKAGE-FREE)")
print("="*80)

# ════════════════════════════════════════════════════════════
# SELECTED FEATURES (7 features)
# ════════════════════════════════════════════════════════════

SELECTED_FEATURES = [
    'reps_mean',                  # Cohen's d: 3.302, corr: -0.761
    'rpe_mean',                   # Cohen's d: 2.211, corr: -0.673
    'total_sets',                 # Cohen's d: 2.612, corr: +0.755
    'acwr_mean',                  # Cohen's d: 2.162, corr: -0.691
    'spike_weeks_count',          # Cohen's d: 1.264, corr: +0.450
    'load_progression',           # Cohen's d: 1.000, corr: +0.432
    'skip_rate'                   # Cohen's d: 3.657, corr: -0.839
    # REMOVED: observed_freq_weekly (Cohen's d: 0.041, non discriminante)
    # REMOVED: consistency_score (correlation: 1.000, LEAKAGE!)
    # REMOVED: rpe_volume_interaction (collineare con rpe_mean × reps_mean)
]

print(f"\n[OK] Selected features: {len(SELECTED_FEATURES)}")
for i, feat in enumerate(SELECTED_FEATURES, 1):
    print(f"  {i}. {feat}")

# ════════════════════════════════════════════════════════════
# VERIFY NO HIGH LEAKAGE
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("LEAKAGE VERIFICATION")
print("-"*80)

for feat in SELECTED_FEATURES:
    corr_val = corr_matrix.loc[feat, 'target_encoded']

    status = "[OK] SAFE" if abs(corr_val) < 0.85 else "[!] HIGH"
    print(f"{feat:25s}: {corr_val:+.3f}  {status}")

# Check max correlation
max_corr = max(abs(corr_matrix.loc[feat, 'target_encoded']) for feat in SELECTED_FEATURES)
print(f"\n[OK] Max absolute correlation: {max_corr:.3f}")

if max_corr < 0.85:
    print("  [OK] ALL FEATURES BELOW LEAKAGE THRESHOLD (0.85)")
else:
    print("  [!] Some features above threshold - review needed")

# ════════════════════════════════════════════════════════════
# FEATURE IMPORTANCE (Cohen's d ranking)
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("FEATURE DISCRIMINATIVE POWER (Cohen's d)")
print("-"*80)

cohens_ranking = []
for feat in SELECTED_FEATURES:
    beg = user_agg[user_agg['experience_label'] == 'Beginner'][feat].dropna()
    adv = user_agg[user_agg['experience_label'] == 'Advanced'][feat].dropna()

    pooled_std = np.sqrt(((len(beg)-1)*beg.std()**2 +
                          (len(adv)-1)*adv.std()**2) / (len(beg)+len(adv)-2))
    cohens_d = abs(beg.mean() - adv.mean()) / pooled_std if pooled_std > 0 else 0.0

    cohens_ranking.append({
        'Feature': feat,
        'Cohens_d': cohens_d,
        'Correlation': corr_matrix.loc[feat, 'target_encoded']
    })

cohens_df = pd.DataFrame(cohens_ranking).sort_values('Cohens_d', ascending=False)

print("\nRanked by discriminative power:\n")
print(cohens_df.to_string(index=False))

print("\n" + "="*80)
print("[OK] Feature Selection v2.2 Complete")
print(f"[OK] Final feature count: {len(SELECTED_FEATURES)}")
print("[OK] Ready for Modeling")
print("="*80)
# Out:
# ================================================================================
# FEATURE SELECTION v2.2 (LEAKAGE-FREE)
# ================================================================================
#
# [OK] Selected features: 7
#   1. reps_mean
#   2. rpe_mean
#   3. total_sets
#   4. acwr_mean
#   5. spike_weeks_count
#   6. load_progression
#   7. skip_rate
#
# --------------------------------------------------------------------------------
# LEAKAGE VERIFICATION
# --------------------------------------------------------------------------------
# reps_mean                : -0.761  [OK] SAFE
# rpe_mean                 : -0.673  [OK] SAFE
# total_sets               : +0.755  [OK] SAFE
# acwr_mean                : -0.691  [OK] SAFE
# spike_weeks_count        : +0.225  [OK] SAFE
# load_progression         : +0.432  [OK] SAFE
# skip_rate                : -0.839  [OK] SAFE
#
# [OK] Max absolute correlation: 0.839
#   [OK] ALL FEATURES BELOW LEAKAGE THRESHOLD (0.85)
#
# --------------------------------------------------------------------------------
# FEATURE DISCRIMINATIVE POWER (Cohen's d)
# --------------------------------------------------------------------------------
#
# Ranked by discriminative power:
#
#           Feature  Cohens_d  Correlation
#         skip_rate  3.656555    -0.839248
#         reps_mean  3.302273    -0.761420
#        total_sets  2.612079     0.754666
#          rpe_mean  2.210898    -0.673387
#         acwr_mean  2.161878    -0.690664
#  load_progression  1.000323     0.432245
# spike_weeks_count  0.607738     0.224695
#
# ================================================================================
# [OK] Feature Selection v2.2 Complete
# [OK] Final feature count: 7
# [OK] Ready for Modeling
# ================================================================================

# %% [markdown]
# #**CELLA 6 - Distribuzione Feature (Histograms Stratificati)**

# %%
# ═══════════════════════════════════════════════════════════
# FEATURE DISTRIBUTIONS - HISTOGRAMS (Stratified by Experience)
# ═══════════════════════════════════════════════════════════

print("="*80)
print("FEATURE DISTRIBUTIONS - HISTOGRAMS")
print("="*80)

# ════════════════════════════════════════════════════════════
# DISTRIBUTION STATISTICS (Numerical Version of Histograms)
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("NUMERICAL DISTRIBUTION ANALYSIS")
print("-"*80)

for feat in dist_features:

    print(f"\n{'='*60}")
    print(f"FEATURE: {feat}")
    print(f"{'='*60}")

    # Statistiche globali
    global_stats = user_agg[feat].describe()

    print("\n[GLOBAL]")
    print(f"Mean      : {global_stats['mean']:.3f}")
    print(f"Std       : {global_stats['std']:.3f}")
    print(f"Min       : {global_stats['min']:.3f}")
    print(f"25%       : {global_stats['25%']:.3f}")
    print(f"Median    : {global_stats['50%']:.3f}")
    print(f"75%       : {global_stats['75%']:.3f}")
    print(f"Max       : {global_stats['max']:.3f}")

    # Statistiche per gruppo
    print("\n[BY EXPERIENCE LEVEL]")

    group_means = {}

    for exp_label in ['Beginner', 'Intermediate', 'Advanced']:
        data = user_agg[user_agg['experience_label'] == exp_label][feat].dropna()

        if len(data) == 0:
            continue

        mean_val = data.mean()
        std_val = data.std()

        group_means[exp_label] = mean_val

        print(f"\n  {exp_label}")
        print(f"    Count  : {len(data)}")
        print(f"    Mean   : {mean_val:.3f}")
        print(f"    Std    : {std_val:.3f}")
        print(f"    Median : {data.median():.3f}")
        print(f"    Min    : {data.min():.3f}")
        print(f"    Max    : {data.max():.3f}")

    # Ordinamento per media (utile per vedere separazione)
    print("\n  → Mean Ranking:")
    for k, v in sorted(group_means.items(), key=lambda x: x[1]):
        print(f"    {k:12s}: {v:.3f}")

print("\n" + "-"*80)


# ════════════════════════════════════════════════════════════
# GROUP SEPARATION CHECK (Mean Differences)
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("GROUP SEPARATION (MEAN DIFFERENCES)")
print("-"*80)

for feat in dist_features:

    means = user_agg.groupby('experience_label')[feat].mean()

    if len(means) < 3:
        continue

    diff_BA = means['Advanced'] - means['Beginner']
    diff_IA = means['Advanced'] - means['Intermediate']
    diff_IB = means['Intermediate'] - means['Beginner']

    print(f"\n{feat}")
    print(f"  Advanced - Beginner     : {diff_BA:+.3f}")
    print(f"  Advanced - Intermediate : {diff_IA:+.3f}")
    print(f"  Intermediate - Beginner : {diff_IB:+.3f}")

    # Flag forte separazione
    if abs(diff_BA) > user_agg[feat].std():
        print("  [STRONG SEPARATION] Difference > 1 STD")


# Feature chiave per distribution analysis
dist_features = [
    'load_mean', 'total_sets', 'spike_weeks_count', 'skip_rate',
    'rpe_mean', 'acwr_mean', 'load_progression', 'reps_mean'
]

fig, axes = plt.subplots(4, 2, figsize=(14, 16))
axes = axes.flatten()

colors = {'Beginner': '#3498db', 'Intermediate': '#2ecc71', 'Advanced': '#e74c3c'}

for idx, feat in enumerate(dist_features):
    ax = axes[idx]

    # Histogram per experience level (overlayed)
    for exp_label in ['Beginner', 'Intermediate', 'Advanced']:
        data = user_agg[user_agg['experience_label'] == exp_label][feat].dropna()

        ax.hist(data, bins=20, alpha=0.5, label=exp_label,
                color=colors[exp_label], edgecolor='black', linewidth=0.5)

    ax.set_xlabel(feat, fontsize=10, weight='bold')
    ax.set_ylabel('Frequency', fontsize=9)
    ax.set_title(f'Distribution: {feat}', fontsize=11, weight='bold')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

plt.suptitle('Feature Distributions by Experience Level',
             fontsize=16, weight='bold', y=0.995)
plt.tight_layout()
plt.savefig('feature_distributions_STATUS_v2.png', dpi=150, bbox_inches='tight')
plt.show()

print("[OK] Histograms saved: feature_distributions_STATUS_v2.png")
print("="*80)
# Out:
# ================================================================================
# FEATURE DISTRIBUTIONS - HISTOGRAMS
# ================================================================================
#
# --------------------------------------------------------------------------------
# NUMERICAL DISTRIBUTION ANALYSIS
# --------------------------------------------------------------------------------
#
# ============================================================
# FEATURE: load_mean
# ============================================================
#
# [GLOBAL]
# Mean      : 40.611
# Std       : 24.942
# Min       : 15.932
# 25%       : 20.524
# Median    : 31.943
# 75%       : 52.484
# Max       : 144.408
#
# [BY EXPERIENCE LEVEL]
#
#   Beginner
#     Count  : 170
#     Mean   : 19.700
#     Std    : 1.570
#     Median : 19.662
#     Min    : 15.932
#     Max    : 25.572
#
#   Intermediate
#     Count  : 170
#     Mean   : 33.447
#     Std    : 5.661
#     Median : 31.943
#     Min    : 22.745
#     Max    : 61.311
#
#   Advanced
#     Count  : 170
#     Mean   : 68.687
#     Std    : 23.554
#     Median : 60.560
#     Min    : 34.156
#     Max    : 144.408
#
#   → Mean Ranking:
#     Beginner    : 19.700
#     Intermediate: 33.447
#     Advanced    : 68.687
#
# ============================================================
# FEATURE: total_sets
# ============================================================
#
# [GLOBAL]
# Mean      : 3072.439
# Std       : 2880.311
# Min       : 125.000
# 25%       : 853.000
# Median    : 2007.000
# 75%       : 4393.000
# Max       : 13527.000
#
# [BY EXPERIENCE LEVEL]
#
#   Beginner
#     Count  : 170
#     Mean   : 723.406
#     Std    : 358.383
#     Median : 661.500
#     Min    : 125.000
#     Max    : 1802.000
#
#   Intermediate
#     Count  : 170
#     Mean   : 2451.335
#     Std    : 1371.330
#     Median : 2106.000
#     Min    : 410.000
#     Max    : 7159.000
#
#   Advanced
#     Count  : 170
#     Mean   : 6042.576
#     Std    : 2857.482
#     Median : 5382.500
#     Min    : 1461.000
#     Max    : 13527.000
#
#   → Mean Ranking:
#     Beginner    : 723.406
#     Intermediate: 2451.335
#     Advanced    : 6042.576
#
# ============================================================
# FEATURE: spike_weeks_count
# ============================================================
#
# [GLOBAL]
# Mean      : 8.704
# Std       : 4.803
# Min       : 0.000
# 25%       : 5.000
# Median    : 8.000
# 75%       : 11.750
# Max       : 25.000
#
# [BY EXPERIENCE LEVEL]
#
#   Beginner
#     Count  : 170
#     Mean   : 6.835
#     Std    : 3.754
#     Median : 7.000
#     Min    : 0.000
#     Max    : 19.000
#
#   Intermediate
#     Count  : 170
#     Mean   : 9.800
#     Std    : 5.138
#     Median : 9.000
#     Min    : 1.000
#     Max    : 24.000
#
#   Advanced
#     Count  : 170
#     Mean   : 9.476
#     Std    : 4.867
#     Median : 9.000
#     Min    : 0.000
#     Max    : 25.000
#
#   → Mean Ranking:
#     Beginner    : 6.835
#     Advanced    : 9.476
#     Intermediate: 9.800
#
# ============================================================
# FEATURE: skip_rate
# ============================================================
#
# [GLOBAL]
# Mean      : 0.133
# Std       : 0.070
# Min       : 0.033
# 25%       : 0.077
# Median    : 0.114
# 75%       : 0.178
# Max       : 0.383
#
# [BY EXPERIENCE LEVEL]
#
#   Beginner
#     Count  : 170
#     Mean   : 0.214
#     Std    : 0.053
#     Median : 0.210
#     Min    : 0.108
#     Max    : 0.383
#
#   Intermediate
#     Count  : 170
#     Mean   : 0.116
#     Std    : 0.029
#     Median : 0.115
#     Min    : 0.033
#     Max    : 0.198
#
#   Advanced
#     Count  : 170
#     Mean   : 0.070
#     Std    : 0.017
#     Median : 0.068
#     Min    : 0.035
#     Max    : 0.117
#
#   → Mean Ranking:
#     Advanced    : 0.070
#     Intermediate: 0.116
#     Beginner    : 0.214
#
# ============================================================
# FEATURE: rpe_mean
# ============================================================
#
# [GLOBAL]
# Mean      : 4.806
# Std       : 0.305
# Min       : 4.036
# 25%       : 4.587
# Median    : 4.811
# 75%       : 4.989
# Max       : 5.646
#
# [BY EXPERIENCE LEVEL]
#
#   Beginner
#     Count  : 170
#     Mean   : 5.097
#     Std    : 0.231
#     Median : 5.075
#     Min    : 4.584
#     Max    : 5.646
#
#   Intermediate
#     Count  : 170
#     Mean   : 4.726
#     Std    : 0.201
#     Median : 4.730
#     Min    : 4.290
#     Max    : 5.120
#
#   Advanced
#     Count  : 170
#     Mean   : 4.594
#     Std    : 0.223
#     Median : 4.595
#     Min    : 4.036
#     Max    : 5.073
#
#   → Mean Ranking:
#     Advanced    : 4.594
#     Intermediate: 4.726
#     Beginner    : 5.097
#
# ============================================================
# FEATURE: acwr_mean
# ============================================================
#
# [GLOBAL]
# Mean      : 1.142
# Std       : 0.063
# Min       : 1.029
# 25%       : 1.094
# Median    : 1.128
# 75%       : 1.182
# Max       : 1.390
#
# [BY EXPERIENCE LEVEL]
#
#   Beginner
#     Count  : 170
#     Mean   : 1.196
#     Std    : 0.065
#     Median : 1.200
#     Min    : 1.029
#     Max    : 1.390
#
#   Intermediate
#     Count  : 170
#     Mean   : 1.139
#     Std    : 0.037
#     Median : 1.137
#     Min    : 1.048
#     Max    : 1.232
#
#   Advanced
#     Count  : 170
#     Mean   : 1.090
#     Std    : 0.023
#     Median : 1.089
#     Min    : 1.032
#     Max    : 1.158
#
#   → Mean Ranking:
#     Advanced    : 1.090
#     Intermediate: 1.139
#     Beginner    : 1.196
#
# ============================================================
# FEATURE: load_progression
# ============================================================
#
# [GLOBAL]
# Mean      : 1.078
# Std       : 0.155
# Min       : 0.949
# 25%       : 1.015
# Median    : 1.033
# 75%       : 1.067
# Max       : 2.000
#
# [BY EXPERIENCE LEVEL]
#
#   Beginner
#     Count  : 170
#     Mean   : 1.011
#     Std    : 0.014
#     Median : 1.013
#     Min    : 0.949
#     Max    : 1.045
#
#   Intermediate
#     Count  : 170
#     Mean   : 1.048
#     Std    : 0.061
#     Median : 1.037
#     Min    : 0.978
#     Max    : 1.534
#
#   Advanced
#     Count  : 170
#     Mean   : 1.175
#     Std    : 0.231
#     Median : 1.084
#     Min    : 0.997
#     Max    : 2.000
#
#   → Mean Ranking:
#     Beginner    : 1.011
#     Intermediate: 1.048
#     Advanced    : 1.175
#
# ============================================================
# FEATURE: reps_mean
# ============================================================
#
# [GLOBAL]
# Mean      : 8.786
# Std       : 0.151
# Min       : 8.555
# 25%       : 8.658
# Median    : 8.733
# 75%       : 8.898
# Max       : 9.211
#
# [BY EXPERIENCE LEVEL]
#
#   Beginner
#     Count  : 170
#     Mean   : 8.957
#     Std    : 0.101
#     Median : 8.953
#     Min    : 8.616
#     Max    : 9.211
#
#   Intermediate
#     Count  : 170
#     Mean   : 8.725
#     Std    : 0.093
#     Median : 8.702
#     Min    : 8.555
#     Max    : 9.037
#
#   Advanced
#     Count  : 170
#     Mean   : 8.676
#     Std    : 0.064
#     Median : 8.658
#     Min    : 8.564
#     Max    : 8.865
#
#   → Mean Ranking:
#     Advanced    : 8.676
#     Intermediate: 8.725
#     Beginner    : 8.957
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# GROUP SEPARATION (MEAN DIFFERENCES)
# --------------------------------------------------------------------------------
#
# load_mean
#   Advanced - Beginner     : +48.987
#   Advanced - Intermediate : +35.240
#   Intermediate - Beginner : +13.746
#   [STRONG SEPARATION] Difference > 1 STD
#
# total_sets
#   Advanced - Beginner     : +5319.171
#   Advanced - Intermediate : +3591.241
#   Intermediate - Beginner : +1727.929
#   [STRONG SEPARATION] Difference > 1 STD
#
# spike_weeks_count
#   Advanced - Beginner     : +2.641
#   Advanced - Intermediate : -0.324
#   Intermediate - Beginner : +2.965
#
# skip_rate
#   Advanced - Beginner     : -0.144
#   Advanced - Intermediate : -0.046
#   Intermediate - Beginner : -0.099
#   [STRONG SEPARATION] Difference > 1 STD
#
# rpe_mean
#   Advanced - Beginner     : -0.503
#   Advanced - Intermediate : -0.132
#   Intermediate - Beginner : -0.371
#   [STRONG SEPARATION] Difference > 1 STD
#
# acwr_mean
#   Advanced - Beginner     : -0.106
#   Advanced - Intermediate : -0.049
#   Intermediate - Beginner : -0.057
#   [STRONG SEPARATION] Difference > 1 STD
#
# load_progression
#   Advanced - Beginner     : +0.164
#   Advanced - Intermediate : +0.128
#   Intermediate - Beginner : +0.036
#   [STRONG SEPARATION] Difference > 1 STD
#
# reps_mean
#   Advanced - Beginner     : -0.281
#   Advanced - Intermediate : -0.049
#   Intermediate - Beginner : -0.232
#   [STRONG SEPARATION] Difference > 1 STD
# [OK] Histograms saved: feature_distributions_STATUS_v2.png
# ================================================================================

# %% [markdown]
# #**CELLA 7 - Violin Plots (Distribuzione + Densità)**

# %%
# ═══════════════════════════════════════════════════════════
# VIOLIN PLOTS - Distribution Density by Experience
# ═══════════════════════════════════════════════════════════

print("="*80)
print("VIOLIN PLOTS - Distribution Density")
print("="*80)

# ════════════════════════════════════════════════════════════
# NUMERICAL ANALYSIS - VIOLIN PLOT EQUIVALENT
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("NUMERICAL DENSITY & EFFECT SIZE ANALYSIS")
print("-"*80)

effect_sizes = []

for feat in violin_features:

    print(f"\n{'='*60}")
    print(f"FEATURE: {feat}")
    print(f"{'='*60}")

    groups = {}

    for exp in ['Beginner', 'Intermediate', 'Advanced']:
        data = user_agg[user_agg['experience_label'] == exp][feat].dropna()
        if len(data) == 0:
            continue

        groups[exp] = data

        print(f"\n  {exp}")
        print(f"    Count   : {len(data)}")
        print(f"    Mean    : {data.mean():.3f}")
        print(f"    Std     : {data.std():.3f}")
        print(f"    Q1      : {data.quantile(0.25):.3f}")
        print(f"    Median  : {data.median():.3f}")
        print(f"    Q3      : {data.quantile(0.75):.3f}")
        print(f"    Min     : {data.min():.3f}")
        print(f"    Max     : {data.max():.3f}")

    # ════════════════════════════════════════════════════════
    # Cohen's d pairwise
    # ════════════════════════════════════════════════════════

    print("\n  → Effect Sizes (Cohen's d):")

    def cohens_d(x, y, eps=1e-8):
      x = pd.Series(x).dropna()
      y = pd.Series(y).dropna()
      nx, ny = len(x), len(y)
      if nx < 2 or ny < 2:
          return np.nan  # non calcolabile

      sx2 = x.var(ddof=1)
      sy2 = y.var(ddof=1)

      pooled_var = ((nx - 1) * sx2 + (ny - 1) * sy2) / (nx + ny - 2)
      pooled_std = np.sqrt(pooled_var)

      if not np.isfinite(pooled_std) or pooled_std < eps:
          return np.nan  # varianza ~0 -> evita numeri assurdi

      return float(abs(x.mean() - y.mean()) / pooled_std)


    if 'Beginner' in groups and 'Advanced' in groups:
        d_BA = cohens_d(groups['Beginner'], groups['Advanced'])
        print(f"    Beginner vs Advanced     : {d_BA:.3f}")
        effect_sizes.append((feat, 'B-A', d_BA))

    if 'Beginner' in groups and 'Intermediate' in groups:
        d_BI = cohens_d(groups['Beginner'], groups['Intermediate'])
        print(f"    Beginner vs Intermediate : {d_BI:.3f}")
        effect_sizes.append((feat, 'B-I', d_BI))

    if 'Intermediate' in groups and 'Advanced' in groups:
        d_IA = cohens_d(groups['Intermediate'], groups['Advanced'])
        print(f"    Intermediate vs Advanced : {d_IA:.3f}")
        effect_sizes.append((feat, 'I-A', d_IA))

print("\n" + "-"*80)


# ════════════════════════════════════════════════════════════
# FEATURE RANKING BY EFFECT SIZE
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("FEATURE RANKING (by max Cohen's d)")
print("-"*80)

ranking = {}

for feat, pair, d in effect_sizes:
    ranking.setdefault(feat, []).append(d)

max_effects = [(feat, max(vals)) for feat, vals in ranking.items()]
max_effects = sorted(max_effects, key=lambda x: x[1], reverse=True)

for feat, max_d in max_effects:
    print(f"{feat:20s}: max d = {max_d:.3f}")

print("-"*80)


# Top 6 discriminative features
violin_features = [
    'skip_rate', 'reps_mean', 'load_mean',
    'total_sets', 'rpe_mean', 'acwr_mean'
]

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

for idx, feat in enumerate(violin_features):
    ax = axes[idx]

    # Violin plot con quartili
    parts = ax.violinplot(
        [user_agg[user_agg['experience_label'] == exp][feat].dropna().values
         for exp in ['Beginner', 'Intermediate', 'Advanced']],
        positions=[1, 2, 3],
        showmeans=True,
        showmedians=True,
        widths=0.7
    )

    # Color by experience
    colors_list = ['#3498db', '#2ecc71', '#e74c3c']
    for pc, color in zip(parts['bodies'], colors_list):
        pc.set_facecolor(color)
        pc.set_alpha(0.6)

    # Styling
    ax.set_xticks([1, 2, 3])
    ax.set_xticklabels(['Beginner', 'Intermediate', 'Advanced'], fontsize=9)
    ax.set_ylabel(feat, fontsize=10, weight='bold')
    ax.set_title(f'{feat}', fontsize=11, weight='bold')
    ax.grid(True, alpha=0.3, axis='y')

    # Add Cohen's d annotation
    beg = user_agg[user_agg['experience_label'] == 'Beginner'][feat].dropna()
    adv = user_agg[user_agg['experience_label'] == 'Advanced'][feat].dropna()

    if len(beg) > 0 and len(adv) > 0:
        pooled_std = np.sqrt(((len(beg)-1)*beg.std()**2 +
                              (len(adv)-1)*adv.std()**2) / (len(beg)+len(adv)-2))
        cohens_d = abs(beg.mean() - adv.mean()) / pooled_std if pooled_std > 0 else 0.0

        ax.text(0.98, 0.98, f"d={cohens_d:.2f}",
                transform=ax.transAxes, fontsize=9, va='top', ha='right',
                bbox=dict(boxstyle='round', facecolor='yellow', alpha=0.6))

plt.suptitle('Violin Plots - Feature Density by Experience',
             fontsize=16, weight='bold', y=0.995)
plt.tight_layout()
plt.savefig('violin_plots_STATUS_v2.png', dpi=150, bbox_inches='tight')
plt.show()

print("[OK] Violin plots saved: violin_plots_STATUS_v2.png")
print("="*80)
# Out:
# ================================================================================
# VIOLIN PLOTS - Distribution Density
# ================================================================================
#
# --------------------------------------------------------------------------------
# NUMERICAL DENSITY & EFFECT SIZE ANALYSIS
# --------------------------------------------------------------------------------
#
# ============================================================
# FEATURE: skip_rate
# ============================================================
#
#   Beginner
#     Count   : 170
#     Mean    : 0.214
#     Std     : 0.053
#     Q1      : 0.175
#     Median  : 0.210
#     Q3      : 0.250
#     Min     : 0.108
#     Max     : 0.383
#
#   Intermediate
#     Count   : 170
#     Mean    : 0.116
#     Std     : 0.029
#     Q1      : 0.098
#     Median  : 0.115
#     Q3      : 0.134
#     Min     : 0.033
#     Max     : 0.198
#
#   Advanced
#     Count   : 170
#     Mean    : 0.070
#     Std     : 0.017
#     Q1      : 0.058
#     Median  : 0.068
#     Q3      : 0.081
#     Min     : 0.035
#     Max     : 0.117
#
#   → Effect Sizes (Cohen's d):
#     Beginner vs Advanced     : 3.657
#     Beginner vs Intermediate : 2.313
#     Intermediate vs Advanced : 1.938
#
# ============================================================
# FEATURE: reps_mean
# ============================================================
#
#   Beginner
#     Count   : 170
#     Mean    : 8.957
#     Std     : 0.101
#     Q1      : 8.893
#     Median  : 8.953
#     Q3      : 9.016
#     Min     : 8.616
#     Max     : 9.211
#
#   Intermediate
#     Count   : 170
#     Mean    : 8.725
#     Std     : 0.093
#     Q1      : 8.659
#     Median  : 8.702
#     Q3      : 8.787
#     Min     : 8.555
#     Max     : 9.037
#
#   Advanced
#     Count   : 170
#     Mean    : 8.676
#     Std     : 0.064
#     Q1      : 8.636
#     Median  : 8.658
#     Q3      : 8.694
#     Min     : 8.564
#     Max     : 8.865
#
#   → Effect Sizes (Cohen's d):
#     Beginner vs Advanced     : 3.302
#     Beginner vs Intermediate : 2.386
#     Intermediate vs Advanced : 0.608
#
# ============================================================
# FEATURE: load_mean
# ============================================================
#
#   Beginner
#     Count   : 170
#     Mean    : 19.700
#     Std     : 1.570
#     Q1      : 18.759
#     Median  : 19.662
#     Q3      : 20.508
#     Min     : 15.932
#     Max     : 25.572
#
#   Intermediate
#     Count   : 170
#     Mean    : 33.447
#     Std     : 5.661
#     Q1      : 29.748
#     Median  : 31.943
#     Q3      : 36.102
#     Min     : 22.745
#     Max     : 61.311
#
#   Advanced
#     Count   : 170
#     Mean    : 68.687
#     Std     : 23.554
#     Q1      : 52.099
#     Median  : 60.560
#     Q3      : 78.020
#     Min     : 34.156
#     Max     : 144.408
#
#   → Effect Sizes (Cohen's d):
#     Beginner vs Advanced     : 2.935
#     Beginner vs Intermediate : 3.309
#     Intermediate vs Advanced : 2.057
#
# ============================================================
# FEATURE: total_sets
# ============================================================
#
#   Beginner
#     Count   : 170
#     Mean    : 723.406
#     Std     : 358.383
#     Q1      : 443.750
#     Median  : 661.500
#     Q3      : 901.500
#     Min     : 125.000
#     Max     : 1802.000
#
#   Intermediate
#     Count   : 170
#     Mean    : 2451.335
#     Std     : 1371.330
#     Q1      : 1386.750
#     Median  : 2106.000
#     Q3      : 3160.500
#     Min     : 410.000
#     Max     : 7159.000
#
#   Advanced
#     Count   : 170
#     Mean    : 6042.576
#     Std     : 2857.482
#     Q1      : 3896.000
#     Median  : 5382.500
#     Q3      : 8057.000
#     Min     : 1461.000
#     Max     : 13527.000
#
#   → Effect Sizes (Cohen's d):
#     Beginner vs Advanced     : 2.612
#     Beginner vs Intermediate : 1.724
#     Intermediate vs Advanced : 1.602
#
# ============================================================
# FEATURE: rpe_mean
# ============================================================
#
#   Beginner
#     Count   : 170
#     Mean    : 5.097
#     Std     : 0.231
#     Q1      : 4.948
#     Median  : 5.075
#     Q3      : 5.282
#     Min     : 4.584
#     Max     : 5.646
#
#   Intermediate
#     Count   : 170
#     Mean    : 4.726
#     Std     : 0.201
#     Q1      : 4.577
#     Median  : 4.730
#     Q3      : 4.888
#     Min     : 4.290
#     Max     : 5.120
#
#   Advanced
#     Count   : 170
#     Mean    : 4.594
#     Std     : 0.223
#     Q1      : 4.432
#     Median  : 4.595
#     Q3      : 4.762
#     Min     : 4.036
#     Max     : 5.073
#
#   → Effect Sizes (Cohen's d):
#     Beginner vs Advanced     : 2.211
#     Beginner vs Intermediate : 1.713
#     Intermediate vs Advanced : 0.622
#
# ============================================================
# FEATURE: acwr_mean
# ============================================================
#
#   Beginner
#     Count   : 170
#     Mean    : 1.196
#     Std     : 0.065
#     Q1      : 1.151
#     Median  : 1.200
#     Q3      : 1.235
#     Min     : 1.029
#     Max     : 1.390
#
#   Intermediate
#     Count   : 170
#     Mean    : 1.139
#     Std     : 0.037
#     Q1      : 1.109
#     Median  : 1.137
#     Q3      : 1.165
#     Min     : 1.048
#     Max     : 1.232
#
#   Advanced
#     Count   : 170
#     Mean    : 1.090
#     Std     : 0.023
#     Q1      : 1.076
#     Median  : 1.089
#     Q3      : 1.105
#     Min     : 1.032
#     Max     : 1.158
#
#   → Effect Sizes (Cohen's d):
#     Beginner vs Advanced     : 2.162
#     Beginner vs Intermediate : 1.070
#     Intermediate vs Advanced : 1.590
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# FEATURE RANKING (by max Cohen's d)
# --------------------------------------------------------------------------------
# skip_rate           : max d = 3.657
# load_mean           : max d = 3.309
# reps_mean           : max d = 3.302
# total_sets          : max d = 2.612
# rpe_mean            : max d = 2.211
# acwr_mean           : max d = 2.162
# --------------------------------------------------------------------------------
# [OK] Violin plots saved: violin_plots_STATUS_v2.png
# ================================================================================

# %% [markdown]
# #**CELLA 9 - Comparison Plots (Beginner vs Advanced)**

# %%
# ═══════════════════════════════════════════════════════════
# COMPARISON PLOTS - Beginner vs Advanced (Detailed)
# ═══════════════════════════════════════════════════════════

print("="*80)
print("COMPARISON PLOTS - Beginner vs Advanced")
print("="*80)

# ════════════════════════════════════════════════════════════
# NUMERICAL COMPARISON - Beginner vs Advanced
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("NUMERICAL COMPARISON (Beginner vs Advanced)")
print("-"*80)

from scipy.stats import ks_2samp

comparison_results = []

def cohens_d(x, y, eps=1e-8):
    x = pd.Series(x).dropna()
    y = pd.Series(y).dropna()
    nx, ny = len(x), len(y)
    if nx < 2 or ny < 2:
        return np.nan  # non calcolabile

    sx2 = x.var(ddof=1)
    sy2 = y.var(ddof=1)

    pooled_var = ((nx - 1) * sx2 + (ny - 1) * sy2) / (nx + ny - 2)
    pooled_std = np.sqrt(pooled_var)

    if not np.isfinite(pooled_std) or pooled_std < eps:
        return np.nan  # varianza ~0 -> evita numeri assurdi

    return float(abs(x.mean() - y.mean()) / pooled_std)


for feat in compare_features:

    beg = user_agg[user_agg['experience_label'] == 'Beginner'][feat].dropna()
    adv = user_agg[user_agg['experience_label'] == 'Advanced'][feat].dropna()

    if len(beg) < 2 or len(adv) < 2:
        continue

    print(f"\n{'='*60}")
    print(f"FEATURE: {feat}")
    print(f"{'='*60}")

    # Statistiche
    print("\n[Beginner]")
    print(f"  Count   : {len(beg)}")
    print(f"  Mean    : {beg.mean():.3f}")
    print(f"  Std     : {beg.std():.3f}")
    print(f"  Median  : {beg.median():.3f}")
    print(f"  Q1/Q3   : {beg.quantile(0.25):.3f} / {beg.quantile(0.75):.3f}")

    print("\n[Advanced]")
    print(f"  Count   : {len(adv)}")
    print(f"  Mean    : {adv.mean():.3f}")
    print(f"  Std     : {adv.std():.3f}")
    print(f"  Median  : {adv.median():.3f}")
    print(f"  Q1/Q3   : {adv.quantile(0.25):.3f} / {adv.quantile(0.75):.3f}")

    # Differenza medie
    mean_diff = adv.mean() - beg.mean()
    print(f"\nMean Difference (Adv - Beg): {mean_diff:+.3f}")

    # Cohen's d
    d = cohens_d(beg, adv)
    if np.isnan(d):
        print("Cohen's d: N/A (varianza ~0)")
    else:
        print(f"Cohen's d: {d:.3f}")

    # KS test (forma distribuzione)
    ks_stat, ks_p = ks_2samp(beg, adv)
    print(f"KS Statistic: {ks_stat:.3f}")
    print(f"KS p-value  : {ks_p:.2e}")

    # Flag interpretazione
    if d > 1.2:
        print("  [VERY STRONG SEPARATION]")
    elif d > 0.8:
        print("  [STRONG SEPARATION]")
    elif d > 0.5:
        print("  [MODERATE SEPARATION]")
    else:
        print("  [WEAK SEPARATION]")

    comparison_results.append((feat, d, ks_stat))

print("\n" + "-"*80)


# ════════════════════════════════════════════════════════════
# FEATURE RANKING (Separation Strength)
# ════════════════════════════════════════════════════════════

print("\n" + "-"*80)
print("FEATURE RANKING - Beginner vs Advanced")
print("-"*80)

ranking = sorted(comparison_results, key=lambda x: x[1], reverse=True)

for feat, d, ks_stat in ranking:
    print(f"{feat:25s} | Cohen's d: {d:.3f} | KS: {ks_stat:.3f}")

print("-"*80)


# Select top discriminative features
compare_features = [
    'skip_rate', 'reps_mean', 'load_mean',
    'total_sets', 'rpe_mean', 'spike_weeks_count'
]

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
axes = axes.flatten()

for idx, feat in enumerate(compare_features):
    ax = axes[idx]

    # Data
    beg_data = user_agg[user_agg['experience_label'] == 'Beginner'][feat].dropna()
    adv_data = user_agg[user_agg['experience_label'] == 'Advanced'][feat].dropna()

    # KDE plot (smoothed histogram)
    from scipy.stats import gaussian_kde

    # Beginner
    if len(beg_data) > 1:
        kde_beg = gaussian_kde(beg_data)
        x_beg = np.linspace(beg_data.min(), beg_data.max(), 200)
        ax.plot(x_beg, kde_beg(x_beg), color='#3498db', linewidth=2.5,
                label='Beginner', alpha=0.8)
        ax.fill_between(x_beg, kde_beg(x_beg), alpha=0.3, color='#3498db')

    # Advanced
    if len(adv_data) > 1:
        kde_adv = gaussian_kde(adv_data)
        x_adv = np.linspace(adv_data.min(), adv_data.max(), 200)
        ax.plot(x_adv, kde_adv(x_adv), color='#e74c3c', linewidth=2.5,
                label='Advanced', alpha=0.8)
        ax.fill_between(x_adv, kde_adv(x_adv), alpha=0.3, color='#e74c3c')

    # Means
    ax.axvline(beg_data.mean(), color='#3498db', linestyle='--', linewidth=1.5, alpha=0.7)
    ax.axvline(adv_data.mean(), color='#e74c3c', linestyle='--', linewidth=1.5, alpha=0.7)

    ax.set_xlabel(feat, fontsize=10, weight='bold')
    ax.set_ylabel('Density', fontsize=9)
    ax.set_title(f'{feat}', fontsize=11, weight='bold')
    ax.legend(fontsize=9, loc='upper right')
    ax.grid(True, alpha=0.3)

    # Cohen's d annotation
    pooled_std = np.sqrt(((len(beg_data)-1)*beg_data.std()**2 +
                          (len(adv_data)-1)*adv_data.std()**2) / (len(beg_data)+len(adv_data)-2))
    cohens_d = abs(beg_data.mean() - adv_data.mean()) / pooled_std if pooled_std > 0 else 0.0

    ax.text(0.02, 0.98, f"Cohen's d: {cohens_d:.2f}\nOverlap: {100*(1-cohens_d/4):.0f}%",
            transform=ax.transAxes, fontsize=8, va='top',
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

plt.suptitle('Density Comparison: Beginner vs Advanced',
             fontsize=16, weight='bold', y=0.995)
plt.tight_layout()
plt.savefig('comparison_beginner_advanced_STATUS_v2.png', dpi=150, bbox_inches='tight')
plt.show()

print("[OK] Comparison plots saved: comparison_beginner_advanced_STATUS_v2.png")
print("="*80)
# Out:
# ================================================================================
# COMPARISON PLOTS - Beginner vs Advanced
# ================================================================================
#
# --------------------------------------------------------------------------------
# NUMERICAL COMPARISON (Beginner vs Advanced)
# --------------------------------------------------------------------------------
#
# ============================================================
# FEATURE: skip_rate
# ============================================================
#
# [Beginner]
#   Count   : 170
#   Mean    : 0.214
#   Std     : 0.053
#   Median  : 0.210
#   Q1/Q3   : 0.175 / 0.250
#
# [Advanced]
#   Count   : 170
#   Mean    : 0.070
#   Std     : 0.017
#   Median  : 0.068
#   Q1/Q3   : 0.058 / 0.081
#
# Mean Difference (Adv - Beg): -0.144
# Cohen's d: 3.657
# KS Statistic: 0.976
# KS p-value  : 1.13e-92
#   [VERY STRONG SEPARATION]
#
# ============================================================
# FEATURE: reps_mean
# ============================================================
#
# [Beginner]
#   Count   : 170
#   Mean    : 8.957
#   Std     : 0.101
#   Median  : 8.953
#   Q1/Q3   : 8.893 / 9.016
#
# [Advanced]
#   Count   : 170
#   Mean    : 8.676
#   Std     : 0.064
#   Median  : 8.658
#   Q1/Q3   : 8.636 / 8.694
#
# Mean Difference (Adv - Beg): -0.281
# Cohen's d: 3.302
# KS Statistic: 0.888
# KS p-value  : 1.27e-70
#   [VERY STRONG SEPARATION]
#
# ============================================================
# FEATURE: load_mean
# ============================================================
#
# [Beginner]
#   Count   : 170
#   Mean    : 19.700
#   Std     : 1.570
#   Median  : 19.662
#   Q1/Q3   : 18.759 / 20.508
#
# [Advanced]
#   Count   : 170
#   Mean    : 68.687
#   Std     : 23.554
#   Median  : 60.560
#   Q1/Q3   : 52.099 / 78.020
#
# Mean Difference (Adv - Beg): +48.987
# Cohen's d: 2.935
# KS Statistic: 1.000
# KS p-value  : 2.07e-101
#   [VERY STRONG SEPARATION]
#
# ============================================================
# FEATURE: total_sets
# ============================================================
#
# [Beginner]
#   Count   : 170
#   Mean    : 723.406
#   Std     : 358.383
#   Median  : 661.500
#   Q1/Q3   : 443.750 / 901.500
#
# [Advanced]
#   Count   : 170
#   Mean    : 6042.576
#   Std     : 2857.482
#   Median  : 5382.500
#   Q1/Q3   : 3896.000 / 8057.000
#
# Mean Difference (Adv - Beg): +5319.171
# Cohen's d: 2.612
# KS Statistic: 0.988
# KS p-value  : 1.19e-96
#   [VERY STRONG SEPARATION]
#
# ============================================================
# FEATURE: rpe_mean
# ============================================================
#
# [Beginner]
#   Count   : 170
#   Mean    : 5.097
#   Std     : 0.231
#   Median  : 5.075
#   Q1/Q3   : 4.948 / 5.282
#
# [Advanced]
#   Count   : 170
#   Mean    : 4.594
#   Std     : 0.223
#   Median  : 4.595
#   Q1/Q3   : 4.432 / 4.762
#
# Mean Difference (Adv - Beg): -0.503
# Cohen's d: 2.211
# KS Statistic: 0.741
# KS p-value  : 1.03e-45
#   [VERY STRONG SEPARATION]
#
# ============================================================
# FEATURE: spike_weeks_count
# ============================================================
#
# [Beginner]
#   Count   : 170
#   Mean    : 6.835
#   Std     : 3.754
#   Median  : 7.000
#   Q1/Q3   : 4.000 / 9.000
#
# [Advanced]
#   Count   : 170
#   Mean    : 9.476
#   Std     : 4.867
#   Median  : 9.000
#   Q1/Q3   : 6.000 / 12.000
#
# Mean Difference (Adv - Beg): +2.641
# Cohen's d: 0.608
# KS Statistic: 0.206
# KS p-value  : 1.44e-03
#   [MODERATE SEPARATION]
#
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# FEATURE RANKING - Beginner vs Advanced
# --------------------------------------------------------------------------------
# skip_rate                 | Cohen's d: 3.657 | KS: 0.976
# reps_mean                 | Cohen's d: 3.302 | KS: 0.888
# load_mean                 | Cohen's d: 2.935 | KS: 1.000
# total_sets                | Cohen's d: 2.612 | KS: 0.988
# rpe_mean                  | Cohen's d: 2.211 | KS: 0.741
# spike_weeks_count         | Cohen's d: 0.608 | KS: 0.206
# --------------------------------------------------------------------------------
# [OK] Comparison plots saved: comparison_beginner_advanced_STATUS_v2.png
# ================================================================================

# %% [markdown]
# #**CELLA 10 - Categorical Analysis (Workout Patterns)**

# %%
# ═══════════════════════════════════════════════════════════
# CATEGORICAL ANALYSIS - Workout Patterns
# ═══════════════════════════════════════════════════════════

print("="*80)
print("CATEGORICAL ANALYSIS - Workout Patterns")
print("="*80)

# ════════════════════════════════════════════════════════════
# NUMERICAL CATEGORICAL ANALYSIS - Workout Patterns
# ════════════════════════════════════════════════════════════

print("\n[INFO] Merging experience_label to df_sets...")
df_sets_with_exp = df_sets.merge(
    df_users[['user_id', 'experience_label']],
    on='user_id',
    how='left'
)
print(f"[OK] Merged: {len(df_sets_with_exp):,} sets with experience labels")

# Week Type Distribution
print("\n" + "-"*80)
print("1. Week Type Distribution by Experience (%)")
print("-"*80)

week_type_dist = df_sets_with_exp.groupby(['experience_label', 'week_type']).size().unstack(fill_value=0)
week_type_pct = week_type_dist.div(week_type_dist.sum(axis=1), axis=0) * 100
print(week_type_pct.round(1))

#Skip Rate Distribution
print("\n" + "-"*80)
print("2. Skip Rate Statistics by Experience")
print("-"*80)

skip_stats = user_agg.groupby('experience_label')['skip_rate'].agg(
    count='count',
    mean='mean',
    std='std',
    min='min',
    q25=lambda x: x.quantile(0.25),
    median=lambda x: x.quantile(0.5),
    q75=lambda x: x.quantile(0.75),
    max='max'
).round(3)

print(skip_stats)

#Total Sets Binned Distribution
print("\n" + "-"*80)
print("3. Total Sets Range Distribution by Experience (%)")
print("-"*80)

bins = [0, 500, 1000, 2000, 4000, 8000, 15000]
labels = ['<500', '500-1k', '1k-2k', '2k-4k', '4k-8k', '8k+']
user_agg['total_sets_bin'] = pd.cut(user_agg['total_sets'], bins=bins, labels=labels)

sets_bin_dist = user_agg.groupby(['experience_label', 'total_sets_bin']).size().unstack(fill_value=0)
sets_bin_pct = sets_bin_dist.div(sets_bin_dist.sum(axis=1), axis=0) * 100
print(sets_bin_pct.round(1))

# 4️Optional: Top categories per group
print("\nTop Week Type per Experience:")
for exp in week_type_pct.index:
    top_type = week_type_pct.loc[exp].idxmax()
    top_pct = week_type_pct.loc[exp].max()
    print(f"  {exp:12s}: {top_type} ({top_pct:.1f}%)")

print("\nTop Total Sets Bin per Experience:")
for exp in sets_bin_pct.index:
    top_bin = sets_bin_pct.loc[exp].idxmax()
    top_pct = sets_bin_pct.loc[exp].max()
    print(f"  {exp:12s}: {top_bin} ({top_pct:.1f}%)")

print("\n" + "="*80)
print("[OK] Numerical Categorical Analysis Complete")
print("="*80)




# ════════════════════════════════════════════════════════════
# MERGE experience_label to df_sets (needed for analysis)
# ════════════════════════════════════════════════════════════

print("\nMerging experience_label to sets data...")

df_sets_with_exp = df_sets.merge(
    df_users[['user_id', 'experience_label']],
    on='user_id',
    how='left'
)

print(f"[OK] Merged: {len(df_sets_with_exp):,} sets with experience labels")

# ════════════════════════════════════════════════════════════
# 1. Week Type Distribution (spike/deload/normal)
# ════════════════════════════════════════════════════════════

print("\n1. Week Type Distribution by Experience...\n")

week_type_dist = df_sets_with_exp.groupby(['experience_label', 'week_type']).size().unstack(fill_value=0)
week_type_pct = week_type_dist.div(week_type_dist.sum(axis=1), axis=0) * 100

print("Week Type Distribution (%):\n")
print(week_type_pct.round(1))

# Grouped bar chart
fig, ax = plt.subplots(figsize=(10, 6))
week_type_pct.plot(kind='bar', stacked=False, ax=ax,
                   color=['#95a5a6', '#e74c3c', '#2ecc71'],
                   width=0.7, edgecolor='black', linewidth=0.5)

ax.set_xlabel('Experience Level', fontsize=12, weight='bold')
ax.set_ylabel('Percentage (%)', fontsize=12)
ax.set_title('Week Type Distribution by Experience Level', fontsize=14, weight='bold')
ax.legend(title='Week Type', fontsize=10)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
ax.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('week_type_distribution_STATUS_v2.png', dpi=150, bbox_inches='tight')
plt.show()

print("[OK] Week type plot saved")

# ════════════════════════════════════════════════════════════
# 2. Skip Rate Distribution
# ════════════════════════════════════════════════════════════

print("\n2. Skip Rate Analysis...\n")

skip_summary = user_agg.groupby('experience_label')['skip_rate'].agg([
    'mean', 'std', 'min', 'max'
]).round(3)

print("Skip Rate Statistics:\n")
print(skip_summary)

# Bar chart con error bars
fig, ax = plt.subplots(figsize=(10, 6))

x_pos = np.arange(len(skip_summary))
means = skip_summary['mean']
stds = skip_summary['std']

bars = ax.bar(x_pos, means, yerr=stds,
              color=['#3498db', '#2ecc71', '#e74c3c'],
              alpha=0.7, edgecolor='black', linewidth=1.5,
              capsize=10, error_kw={'linewidth': 2})

ax.set_xlabel('Experience Level', fontsize=12, weight='bold')
ax.set_ylabel('Skip Rate', fontsize=12)
ax.set_title('Skip Rate by Experience Level (mean ± std)', fontsize=14, weight='bold')
ax.set_xticks(x_pos)
ax.set_xticklabels(skip_summary.index)
ax.grid(True, alpha=0.3, axis='y')

# Add value labels on bars
for i, (bar, mean_val) in enumerate(zip(bars, means)):
    height = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2., height,
            f'{mean_val:.2%}',
            ha='center', va='bottom', fontsize=11, weight='bold')

plt.tight_layout()
plt.savefig('skip_rate_by_experience_STATUS_v2.png', dpi=150, bbox_inches='tight')
plt.show()

print("[OK] Skip rate plot saved")

# ════════════════════════════════════════════════════════════
# 3. Total Sets Range Analysis
# ════════════════════════════════════════════════════════════

print("\n3. Total Sets Range Analysis...\n")

# Define bins (experience-aware)
bins = [0, 500, 1000, 2000, 4000, 8000, 15000]
labels = ['<500', '500-1k', '1k-2k', '2k-4k', '4k-8k', '8k+']

user_agg['total_sets_bin'] = pd.cut(user_agg['total_sets'], bins=bins, labels=labels)

sets_bin_dist = user_agg.groupby(['experience_label', 'total_sets_bin']).size().unstack(fill_value=0)
sets_bin_pct = sets_bin_dist.div(sets_bin_dist.sum(axis=1), axis=0) * 100

print("Total Sets Distribution (%):\n")
print(sets_bin_pct.round(1))

# Grouped bar chart
fig, ax = plt.subplots(figsize=(12, 6))
sets_bin_pct.T.plot(kind='bar', ax=ax,
                    color=['#3498db', '#2ecc71', '#e74c3c'],
                    width=0.8, edgecolor='black', linewidth=0.5)

ax.set_xlabel('Total Sets Range', fontsize=12, weight='bold')
ax.set_ylabel('Percentage (%)', fontsize=12)
ax.set_title('Total Sets Distribution by Experience Level', fontsize=14, weight='bold')
ax.legend(title='Experience', fontsize=10)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('total_sets_distribution_STATUS_v2.png', dpi=150, bbox_inches='tight')
plt.show()

print("[OK] Total sets distribution plot saved")

print("\n" + "="*80)
print("[OK] Categorical Analysis Complete")
print("="*80)
# Out:
# ================================================================================
# CATEGORICAL ANALYSIS - Workout Patterns
# ================================================================================
#
# [INFO] Merging experience_label to df_sets...
# [OK] Merged: 1,566,944 sets with experience labels
#
# --------------------------------------------------------------------------------
# 1. Week Type Distribution by Experience (%)
# --------------------------------------------------------------------------------
# week_type         deload  normal  spike
# experience_label
# Advanced             5.4    86.1    8.4
# Beginner             2.0    71.5   26.5
# Intermediate         3.6    79.9   16.5
#
# --------------------------------------------------------------------------------
# 2. Skip Rate Statistics by Experience
# --------------------------------------------------------------------------------
#                   count   mean    std    min    q25  median    q75    max
# experience_label
# Advanced            170  0.070  0.017  0.035  0.058   0.068  0.081  0.117
# Beginner            170  0.214  0.053  0.108  0.175   0.210  0.250  0.383
# Intermediate        170  0.116  0.029  0.033  0.098   0.115  0.134  0.198
#
# --------------------------------------------------------------------------------
# 3. Total Sets Range Distribution by Experience (%)
# --------------------------------------------------------------------------------
# total_sets_bin    <500  500-1k  1k-2k  2k-4k  4k-8k   8k+
# experience_label
# Advanced           0.0     0.0    2.4   25.3   47.1  25.3
# Beginner          32.4    49.4   18.2    0.0    0.0   0.0
# Intermediate       1.2     8.8   37.1   38.2   14.7   0.0
#
# Top Week Type per Experience:
#   Advanced    : normal (86.1%)
#   Beginner    : normal (71.5%)
#   Intermediate: normal (79.9%)
#
# Top Total Sets Bin per Experience:
#   Advanced    : 4k-8k (47.1%)
#   Beginner    : 500-1k (49.4%)
#   Intermediate: 2k-4k (38.2%)
#
# ================================================================================
# [OK] Numerical Categorical Analysis Complete
# ================================================================================
#
# Merging experience_label to sets data...
# /tmp/ipython-input-3462838832.py:57: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sets_bin_dist = user_agg.groupby(['experience_label', 'total_sets_bin']).size().unstack(fill_value=0)
# [OK] Merged: 1,566,944 sets with experience labels
#
# 1. Week Type Distribution by Experience...
#
# Week Type Distribution (%):
#
# week_type         deload  normal  spike
# experience_label
# Advanced             5.4    86.1    8.4
# Beginner             2.0    71.5   26.5
# Intermediate         3.6    79.9   16.5
# [OK] Week type plot saved
#
# 2. Skip Rate Analysis...
#
# Skip Rate Statistics:
#
#                    mean    std    min    max
# experience_label
# Advanced          0.070  0.017  0.035  0.117
# Beginner          0.214  0.053  0.108  0.383
# Intermediate      0.116  0.029  0.033  0.198
# [OK] Skip rate plot saved
#
# 3. Total Sets Range Analysis...
#
# Total Sets Distribution (%):
#
# total_sets_bin    <500  500-1k  1k-2k  2k-4k  4k-8k   8k+
# experience_label
# Advanced           0.0     0.0    2.4   25.3   47.1  25.3
# Beginner          32.4    49.4   18.2    0.0    0.0   0.0
# Intermediate       1.2     8.8   37.1   38.2   14.7   0.0
# /tmp/ipython-input-3462838832.py:183: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sets_bin_dist = user_agg.groupby(['experience_label', 'total_sets_bin']).size().unstack(fill_value=0)
# [OK] Total sets distribution plot saved
#
# ================================================================================
# [OK] Categorical Analysis Complete
# ================================================================================
